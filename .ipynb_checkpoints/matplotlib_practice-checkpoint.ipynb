# %%
# %matplotlib inline

# %%
#Import dependencies
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Using object-oritented interface method:
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Can also be written as: Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()

ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
#To change figure-level attributes (such as axis labels, a title, or a legend) or save the figure as an image, use
fig = plt.figure()

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
#Skill Drill using object-oriented approach:
# 1. Change line color to green
# 2. Change the marker to a diamond
# 3. Change the line width to 2 points
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis,marker="d", color="green", linewidth=2, label='Boston')

# 4. Add a legend for the city of Boston.
ax.legend()

#5. Add a title and axes label.
ax.set_title("PyBer Fare By Month")
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")

# 6. Add a y-axis limit
ax.set_ylim(0,50)

#7. Add grid lines
ax.grid()

# %%
# **Creating Bar Chart using MATLAB method**

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# To Create a VERTICAL BAR CHART

#Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# To annotate the bar chart:

# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# To create a HORIZONTAL BAR CHART using MATLAB method.

# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# To invert the axis:

plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# To invert y-axis to have months in ascending order:

#create the plot
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
#Skill Drill: Using Matplotlib MATLAB approach, make the following changes:

#1. Change the car colors to magenta:
plt.barh(x_axis, y_axis, color="magenta", label="Boston")
plt.gca().invert_yaxis()

#2. Add a legend for the city of Boston.
plt.legend()

#3. Add a title and axes labels.
plt.title("PyBer Fare By Month")
plt.xlabel("Fare($)")
plt.ylabel("Date")
# Out:
# Text(0, 0.5, 'Date')

# %%
# Creating bar charts using Object Oriented Approach

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()

fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)

#To change bar graph color to black with a legend for the city of New York:
ax.bar(x_axis, y_axis, color="black", label="New York")
# Out:
# <BarContainer object of 12 artists>

# %%
#Create a Horizontal Bar Chart
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# For data on opposite axes, need to switch arguments in the barh() function:

fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Skill Drill: Using the object oriented approach, make the following changes:

#1. Change the bar color to cyan:


#2. Add a legend for the city of Chicago


#3. Add a title and axes labels.


#4. Switch the axis so the fare data in on the x_axis
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="c", label="Chicago")

ax.legend()

ax.set_title("PyBer Fare by Month")
ax.set_xlabel("Fare($)")
ax.set_ylabel("Date")
ax.invert_yaxis()

# %%
#Create a SCATTERPLOT Using MATLAB method

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
plt.scatter(x_axis, y_axis)

# %%
#Skill Drill: Using MatPlotib MATLAB plotting approach, make the following changes to your scatter plot:

#1. Change the color of the markers to red.


#2.Add a legend for the city of Chicago.


#3. Add a title and axes labels.


#4. Switch the axis so that Fare($) is on the x-axis
plt.scatter(y_axis, x_axis, c="red", label="Chicago")
plt.legend()
plt.title("PyBer Fare by Month")
plt.ylabel("Date")
plt.xlabel("Fare($)")
# Out:
# Text(0.5, 0, 'Fare($)')

# %%
# Create a Bubble Chart Using the MATLAB method

plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
# Using Python's list comprehension
# new_list = [expression for item in list if conditional]
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
# Create a Scatter Plot Using the Object-Oriented Interface

fig, ax= plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# Create a Bubble Chart Using the Object-Oriented Interface

fig, ax=plt.subplots()
ax.scatter(x_axis,y_axis, s=y_axis)

# %%
#Skill Drill: Using the object oriented approach, make the following changes to your bubble chart:

#1. Change the color of the markers to sky blue:
fig, ax=plt.subplots()
ax.scatter(x_axis,y_axis, s=y_axis, c="skyblue")

#2. Change the size of the markers to 5 times each data point.
ax.scatter(x_axis, y_axis, s = [i * 5 for i in y_axis], c="skyblue")

#3. Make the color 20% transparent.
ax.scatter(x_axis, y_axis, s = [i * 5 for i in y_axis], c="skyblue", alpha=0.2)

#4. Add a black edge around the circles.
ax.scatter(x_axis, y_axis, s = [i * 5 for i in y_axis], c="skyblue", alpha=0.2, edgecolor="black")

#5. Make the linewidth of the circles 2 points.
ax.scatter(x_axis, y_axis, s = [i * 5 for i in y_axis], c="skyblue", alpha=0.2, edgecolor="black", linewidth=2.0)

#6. Add a legend for the city of Boston.
ax.scatter(x_axis, y_axis, s = [i * 5 for i in y_axis], c="skyblue", alpha=0.2, edgecolor="black", linewidth=2.0, label="Boston")
ax.legend()

#7. Add a title
ax.set_title("PyBer Fare by Month")




#9. Add a limit for the x-axis data.

#10. Invert the y-axis so that January is at the top.
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')

# %%
#8. Swtich the axis so that the Fare($) data on the x-axis.
fig, ax=plt.subplots()
ax.scatter(y_axis, x_axis, s = [i * 5 for i in y_axis], c="skyblue", alpha=0.5, edgecolor="black", linewidth=2.0, label="Boston")
ax.legend()


#9. Add a limit for the x-axis data.
ax.set_xlim(0,50)

#10. Invert the y-axis so that January is at the top.
ax.set_title("PyBer Fare by Month")
ax.set_xlabel("Fare($)")
ax.set_ylabel("Date")
ax.invert_yaxis()

# %%
# Creating Pie Charts using MATLAB method

plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x269d1a6f648>,
#   <matplotlib.patches.Wedge at 0x269d1a75888>,
#   <matplotlib.patches.Wedge at 0x269d1a7c688>,
#   <matplotlib.patches.Wedge at 0x269d1a7c188>,
#   <matplotlib.patches.Wedge at 0x269d1a8b648>,
#   <matplotlib.patches.Wedge at 0x269d1a92748>,
#   <matplotlib.patches.Wedge at 0x269d1a98708>,
#   <matplotlib.patches.Wedge at 0x269d1a9d748>,
#   <matplotlib.patches.Wedge at 0x269d1a8b588>,
#   <matplotlib.patches.Wedge at 0x269d1a92688>,
#   <matplotlib.patches.Wedge at 0x269d1a6f548>,
#   <matplotlib.patches.Wedge at 0x269d1aba688>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883322, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.12730228640479738, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
# Create a pie chart using the Object-Oriented Interface

fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()

# %%
#Skill Drill: Using the Object-Oriented Approach, make the following changes to the pie chart:

#1. Add a percentage to one decimal place to each wedge of the pie.
fig, ax = plt.subplots()
ax.pie(y_axis, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x269d1a22508>,
#   <matplotlib.patches.Wedge at 0x269d19d5bc8>,
#   <matplotlib.patches.Wedge at 0x269d19d0d48>,
#   <matplotlib.patches.Wedge at 0x269d1a2f148>,
#   <matplotlib.patches.Wedge at 0x269d19c9e48>,
#   <matplotlib.patches.Wedge at 0x269d19b23c8>,
#   <matplotlib.patches.Wedge at 0x269d19a7988>,
#   <matplotlib.patches.Wedge at 0x269d19de948>,
#   <matplotlib.patches.Wedge at 0x269d19c94c8>,
#   <matplotlib.patches.Wedge at 0x269d19b27c8>,
#   <matplotlib.patches.Wedge at 0x269d1a22308>,
#   <matplotlib.patches.Wedge at 0x269d19ad748>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.7729302540020312, -0.782674148319948, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883322, '8.9%'),
#   Text(-0.42159832036474426, -0.4269131718108807, '14.5%'),
#   Text(-0.12730228640479738, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
#2. Increase the figure size to 8x8
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%') 
plt.show()

# %%
#3. Explode the two highest percentage months.
fig, ax = plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
ax.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%') 
plt.show()

# %%
#4. Add a shadow.
fig, ax = plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
ax.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%', shadow=True) 
plt.show()

# %%
#5. Add a start angle so that January is at the top.
fig, ax = plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
ax.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%', shadow=True, startangle=85) 
plt.show()

# %%
#6. Reverse the order so that the month order is in a clockwise direction.
fig, ax = plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
ax.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%', shadow=True, startangle=85, counterclock=False)
plt.show()
